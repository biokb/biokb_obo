# %%
from owlready2 import get_ontology

# %%
onto = get_ontology(f"file:///home/ceb/.biokb/obo/data/mondo.owl").load()


def obo_id(entity):
    return entity.iri.split("/")[-1]


for cls in onto.classes():
    if isinstance(cls.label, list):
        # print(cls.label[0])
        pass
    else:
        if cls.label:
            print(cls.label)
